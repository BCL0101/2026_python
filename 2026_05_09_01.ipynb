# %% [markdown]
# <a href="https://colab.research.google.com/github/BCL0101/2026_python/blob/main/2026_05_09_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Python!")
# Out:
# Hello! Python!

# %% [markdown]
# ### 這是第一節上課的講義
# 下面是數學運算的介紹
#
# 先介紹*變數*,**數學運算子**
#
# #### 專用名詞介紹
#
# - 變數
# - 數學運算子
#
# 1. 運算子,運算元
# 2. 運算式,敘述式
