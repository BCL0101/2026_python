# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                       [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1    0.259772
#    2    0.061540
#    3    1.215948
# b  1   -0.449339
#    2   -1.193064
# c  3    0.160231
#    1    0.032246
# d  2    0.377001
#    3    1.161595
# dtype: float64

# %%
data1 = data.unstack()   # 寬資料
data1
# Out:
#           1         2         3
# a  0.259772  0.061540  1.215948
# b -0.449339 -1.193064       NaN
# c  0.032246       NaN  0.160231
# d       NaN  0.377001  1.161595

# %%
data1.stack()   # 長資料
# Out:
# a  1    0.259772
#    2    0.061540
#    3    1.215948
# b  1   -0.449339
#    2   -1.193064
#    3         NaN
# c  1    0.032246
#    2         NaN
#    3    0.160231
# d  1         NaN
#    2    0.377001
#    3    1.161595
# dtype: float64
