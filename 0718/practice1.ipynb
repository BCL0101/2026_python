# %%
import numpy as np
from numpy import ndarray
import pandas as pd
from pandas import DataFrame

scores:ndarray | None = None # 學生的分數
scores_df:DataFrame | None = None # 學生分數的DataFrame

scores = np.random.randint(50, 101, size=(50, 5))
scores_df = pd.DataFrame(scores,            
            columns=['國文', '英文', '數學', '地理', '歷史'],
            index=range(1,51))
scores_df.T

# %%
import numpy as np
from numpy import ndarray
import pandas as pd
from pandas import DataFrame

scores:ndarray | None = None # 學生的分數
scores_df:DataFrame | None = None # 學生分數的DataFrame

scores = np.random.randint(50, 101, size=(50, 5))
scores_df = pd.DataFrame(scores,            
            columns=['國文', '英文', '數學', '地理', '歷史'],
            index=range(1,51))

names_df:DataFrame = pd.read_csv('students.csv')
scores_df[['姓名','性別']] = names_df[['姓名','性別']].head(n=50).values
scores_df = scores_df[['姓名', '性別','國文', '英文', '數學', '地理', '歷史']]
scores_df
# Out:
#      姓名 性別   國文  英文   數學   地理   歷史
# 1   劉怡君  女   53  59   85   66   50
# 2   黃詩涵  女   64  80   79   98   94
# 3   郭柏翰  男   93  60   71   82   62
# 4   王家豪  男   65  98   98   69   85
# 5   鄭詩涵  女   63  70   65   57   57
# 6   鄭怡君  女   59  50   72   89   55
# 7   蔡詩涵  女   85  66   85   50   80
# 8   李柏翰  男   56  89   81   76   99
# 9   賴怡君  女   57  73   66   76   89
# 10  楊欣怡  女   95  67   81   98   70
# 11  吳冠宇  男   80  56   69   68   93
# 12  許詩涵  女   60  66   89   91   62
# 13  廖志明  男   87  81   55   52   53
# 14  張詩涵  女   96  53   71   89   58
# 15  許冠宇  男   85  52   88   56  100
# 16  曾俊傑  男   86  83   51   70   81
# 17  張志明  男   99  51   80   75   56
# 18  鄭冠宇  男   83  99   52   66   63
# 19  邱佳蓉  女   89  74   91   93   75
# 20  許怡君  女   81  55   63   74   80
# 21  邱柏翰  男   55  70   57   51   96
# 22  蔡志明  男   60  80   58   77   51
# 23  王志明  男   51  77   88   56   56
# 24  王怡君  女   76  59   64   67   71
# 25  洪冠宇  男   52  54   97   75   65
# 26  蔡欣怡  女   92  52   69   96   91
# 27  洪柏翰  男   88  53   75   74   56
# 28  林冠宇  男   54  63   90  100   90
# 29  楊雅婷  女   60  61   70   86   74
# 30  謝怡君  女   75  97   91   60   84
# 31  曾志明  男   75  78   97   62   51
# 32  謝柏翰  男   92  83   90   51   60
# 33  黃柏翰  男   60  79   53   54   75
# 34  劉家豪  男   83  55   85   57   86
# 35  徐怡君  女  100  72   69   89   76
# 36  曾柏翰  男   94  56   51   58   95
# 37  楊柏翰  男   65  74   61   59   95
# 38  許柏翰  男   71  53   54   77   56
# 39  廖冠宇  男   90  68   82   82   81
# 40  廖怡君  女   56  80   70   90   73
# 41  陳柏翰  男   78  95   64   98   72
# 42  劉詩涵  女   89  92  100   80   67
# 43  陳怡君  女   83  92   93   94   95
# 44  張怡君  女   64  63   97   73   76
# 45  李雅婷  女   80  70   94   69   62
# 46  賴俊傑  男   69  73   69   63   80
# 47  林柏翰  男   57  98   65   55   90
# 48  劉志明  男   83  71   96   77   92
# 49  邱欣怡  女   51  61   96   75   81
# 50  曾家豪  男   56  85   50   94   89
